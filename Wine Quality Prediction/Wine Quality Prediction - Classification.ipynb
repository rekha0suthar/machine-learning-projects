# %% [markdown]
# ## Importing Modules

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Loading Dataset

# %%
df = pd.read_csv('WineQT.csv')
df.drop(columns = ['Id'], inplace=True)
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %% [markdown]
# ## Analyzing Data

# %%
# statistical info of data
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             21.000000     0.995570
# 50%       0.079000            13.000000             37.000000     0.996680
# 75%       0.090000            21.000000             61.000000     0.997845
# max       0.611000            68.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1143.000000  1143.000000  1143.000000  1143.000000
# mean      3.311015     0.657708    10.442111     5.657043
# std       0.156664     0.170399     1.082196     0.805824
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.205000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
# datatype info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 107.3 KB

# %% [markdown]
# ## Preprocessing Data

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# create box plot
fig, ax = plt.subplots(ncols = 6, nrows = 2, figsize = (20, 10))
index = 0
ax = ax.flatten()

for col, value in df.items():
    sns.boxplot(value, ax=ax[index])
    index+=1
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)

# %%
# create dist plot
fig, ax = plt.subplots(ncols = 6, nrows = 2, figsize = (20, 10))
index = 0
ax = ax.flatten()

for col, value in df.items():
    sns.distplot(value, ax=ax[index])
    index+=1
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)

# %%
df['total sulfur dioxide'] = np.log(df['total sulfur dioxide'] + 1)
sns.distplot(df['total sulfur dioxide'])
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='Density'>

# %%
df['free sulfur dioxide'] = np.log(df['free sulfur dioxide'] + 1)
sns.distplot(df['free sulfur dioxide'])
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='Density'>

# %%
sns.countplot(df['quality'])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %% [markdown]
# ## Correlation Matrix

# %%
corr = df.corr()
plt.figure(figsize = (20, 10))
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Train-Test Split

# %%
# define Input and Output variables
X = df.drop(columns = ['quality'], axis = 1)
y = df['quality']

# %% [markdown]
# ## Class Imbalancement

# %%
y.value_counts()
# Out:
# 5    483
# 6    462
# 7    143
# 4     33
# 8     16
# 3      6
# Name: quality, dtype: int64

# %%
pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\users\rekha\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\rekha\anaconda3\lib\site-packages (from imblearn) (0.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\rekha\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (2.2.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\rekha\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.21.5)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\rekha\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.0.2)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\rekha\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.9.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\rekha\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import SMOTE
oversample = SMOTE(k_neighbors=4)
# transform the dataset
X, y = oversample.fit_resample(X, y)

# %%
y.value_counts()
# Out:
# 5    483
# 6    483
# 7    483
# 4    483
# 8    483
# 3    483
# Name: quality, dtype: int64

# %% [markdown]
# ## Model Training

# %%
from sklearn.model_selection import cross_val_score, train_test_split

def train(model, X, y):
    # train the model
    x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
    model.fit(x_train, y_train)
    
    print("Accuracy: ", model.score(x_test, y_test)*100)
    
    # Perform Cross Validation
    cv_score = cross_val_score(model, X, y, cv=5)
    cv_score = np.mean(cv_score)*100
    
    print("CV Score: ", cv_score)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

train(model, X, y)
# Out:
# Accuracy:  55.86206896551724
# CV Score:  53.69275206956108

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
train(model, X, y)
# Out:
# Accuracy:  78.3448275862069
# CV Score:  74.05103924721577

# %%
# Model Training with RandomForest and ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
model = RandomForestClassifier()

train(model, X, y)
# Out:
# Accuracy:  87.58620689655172
# CV Score:  82.64379727234828

# %%
model = ExtraTreesClassifier()

train(model, X, y)
# Out:
# Accuracy:  87.72413793103449
# CV Score:  83.16139598594485

# %% [markdown]
# ## Hyper Parameters Tunning

# %%
model = RandomForestClassifier(n_estimators=100, min_samples_split=5, max_depth=7, max_features=1)
train(model, X, y)
# Out:
# Accuracy:  78.20689655172414
# CV Score:  75.32797331903997
